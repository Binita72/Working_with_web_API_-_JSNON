# %% [markdown]
# # Project 2: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# ### Loading the required libraries

# %%
import pandas as pd
import json

# %% [markdown]
# ## Importing Data from JSON files

# %%
with open(r"C:\Users\Binita Mandal\Desktop\Project 1 materials\Project_02_Materials\blockbusters.json") as f:
    data = json.load(f)

# %%
# Lets checkout how the data looks like
data
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
# ...

# %%
# As we are working with json format, lets see the type of it
type(data)
# Out:
# list

# %%
# So from above we can see that its list, lets get total length of it,
len(data)
# Out:
# 18

# %%
# Lets see what we have in first row
data[0]
# Out:
# {'title': 'Avengers: Endgame',
#  'id': 299534,
#  'revenue': 2797800564,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'}],
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'runtime': 181}

# %% [markdown]
# #### Here the data has length of 18, and first row starts with "title", we can easily use "DataFrame" method to get the frame of the file, so lets do it.

# %%
# Creating new data as df
df = pd.DataFrame(data)
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
# We can also use below method to read json file
# Orient is used to know the format of the JSON string,like how exactly the output will look like for every parameter
df = pd.read_json(r"C:\Users\Binita Mandal\Desktop\Project 1 materials\Project_02_Materials\blockbusters.json", orient = "record")
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
# Lets get the information of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 992.0+ bytes

# %% [markdown]
# #### So here we have 6 columns with 3-int & 3-objects. So lets get some idea about it individually

# %%
df.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
# Lets normalize the data by using below syntax
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
# Lets test for "genres"
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
# As we have normalize the data, we can aslo use record path along with adding the "title" and "id". But we have row called "id" already so we can use recorf_prefix to replace it.
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"],
                  record_prefix = "genre_")
# Out:
#     genre_id       genre_name                                         title  \
# 0         12        Adventure                             Avengers: Endgame
# 1        878  Science Fiction                             Avengers: Endgame
# 2         28           Action                             Avengers: Endgame
# 3         28           Action                                        Avatar
# 4         12        Adventure                                        Avatar
# 5         14          Fantasy                                        Avatar
# 6        878  Science Fiction                                        Avatar
# 7         28           Action                  Star Wars: The Force Awakens
# 8         12        Adventure                  Star Wars: The Force Awakens
# 9        878  Science Fiction                  Star Wars: The Force Awakens
# 10        14          Fantasy                  Star Wars: The Force Awakens
# ...

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %%
# This is my API key for TMDB site
api_key  = "api_key=b24db5cb3b745eb8ab758a0a764812c9"

# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
# Here I am going to test by using one movie id
movie_id = 140607

# %%
# Using URL of movie
movie_api = "https://api.themoviedb.org/3/movie/{}?"
movie_api
# Out:
# 'https://api.themoviedb.org/3/movie/{}?'

# %% [markdown]
# #### So here I have URL link that can be accessed by typing it in any browser

# %%
# Here I have got url by formating and the combinig it with my api key
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=b24db5cb3b745eb8ab758a0a764812c9'

# %%
# Lets get the request
r = requests.get(url)
r
# Out:
# <Response [200]>

# %% [markdown]
# #### So I have 200 response from url, so I am going to use it for json file

# %%
data = r.json()

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  'budget': 245000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#  'id': 140607,
#  'imdb_id': 'tt2488496',
#  'original_language': 'en',
#  'original_title': 'Star Wars: The Force Awakens',
#  'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#  'popularity': 90.53,
#  'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#  'production_companies': [{'id': 1634,
#    'logo_path': None,
#    'name': 'Truenorth Productions',
# ...

# %%
type(data)
# Out:
# dict

# %% [markdown]
# #### As the type of the data is "dict", we cant use "DataFrame", So I am going to use "Series" to get the result

# %%
pd.Series(data)
# Out:
# adult                                                                False
# backdrop_path                             /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# belongs_to_collection    {'id': 10, 'name': 'Star Wars Collection', 'po...
# budget                                                           245000000
# genres                   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# homepage                 http://www.starwars.com/films/star-wars-episod...
# id                                                                  140607
# imdb_id                                                          tt2488496
# original_language                                                       en
# original_title                                Star Wars: The Force Awakens
# overview                 Thirty years after defeating the Galactic Empi...
# popularity                                                           90.53
# ...

# %%
# Lets frame it now
df = pd.Series(data).to_frame().T
df
# Out:
#    adult                     backdrop_path  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview popularity  \
# 0  Thirty years after defeating the Galactic Empi...      90.53
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1634, 'logo_path': None, 'name': 'True...
#
# ...

# %%
# Normalising it
pd.json_normalize(data, sep = "_")
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg  245000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview  popularity  \
# 0  Thirty years after defeating the Galactic Empi...       90.53
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1634, 'logo_path': None, 'name': 'True...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
# ...

# %%
# Lets see for "genre"
pd.json_normalize(data = data, record_path = "genres", meta = "title")
# Out:
#     id             name                         title
# 0   28           Action  Star Wars: The Force Awakens
# 1   12        Adventure  Star Wars: The Force Awakens
# 2  878  Science Fiction  Star Wars: The Force Awakens
# 3   14          Fantasy  Star Wars: The Force Awakens

# %%
# same for the "production companies"
pd.json_normalize(data = data, record_path = "production_companies", meta = "title")
# Out:
#       id                         logo_path                   name  \
# 0   1634                              None  Truenorth Productions
# 1      1  /o86DbpburjxrqAzEDhXZcyE8pDb.png         Lucasfilm Ltd.
# 2  11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png              Bad Robot
#
#   origin_country                         title
# 0             IS  Star Wars: The Force Awakens
# 1             US  Star Wars: The Force Awakens
# 2             US  Star Wars: The Force Awakens

# %% [markdown]
# ### So we have now "id", "logo_path", "name", "origin_county" & "title"

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %% [markdown]
# ### Loading the required libraries

# %%
# Here I am going to limit columns by 30
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
discover_api = "https://api.themoviedb.org/3/discover/movie?"

# %%
# query
query = "&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29&page=2"

# %%
# Getting url
url = discover_api+api_key+query

# %%
# Requesting to get url in json format
data = requests.get(url).json()

# %%
# Lets check out the data
data
# Out:
# {'page': 2,
#  'results': [{'adult': False,
#    'backdrop_path': '/oj9pEWQq5higRzKWiE8f0d5hBSb.jpg',
#    'genre_ids': [53, 27, 18],
#    'id': 617708,
#    'original_language': 'es',
#    'original_title': 'La Llorona',
#    'overview': 'A tale of horror and fantasy, ripe with suspense, and an urgent metaphor of Guatemalan recent history and its unhealed political wounds.',
#    'popularity': 60.65,
#    'poster_path': '/2AmTEIwxy1VkcZe32Fs34S37qJ2.jpg',
#    'release_date': '2020-01-22',
#    'title': 'La Llorona',
#    'video': False,
#    'vote_average': 6,
#    'vote_count': 100},
#   {'adult': False,
#    'backdrop_path': '/yFRpUmsreYO5Bc0HVBTsJsHIIox.jpg',
#    'genre_ids': [18, 12, 10751],
#    'id': 481848,
#    'original_language': 'en',
#    'original_title': 'The Call of the Wild',
# ...

# %%
# Converting it to dataframe
pd.DataFrame(data)
# Out:
#     page                                            results  total_pages  \
# 0      2  {'adult': False, 'backdrop_path': '/oj9pEWQq5h...          171
# 1      2  {'adult': False, 'backdrop_path': '/yFRpUmsreY...          171
# 2      2  {'adult': False, 'backdrop_path': '/jZ6NrikuKX...          171
# 3      2  {'adult': False, 'backdrop_path': '/hqYe7wfxv6...          171
# 4      2  {'adult': False, 'backdrop_path': '/p9tdFuUe1X...          171
# 5      2  {'adult': False, 'backdrop_path': '/a8ppJJIQmE...          171
# 6      2  {'adult': False, 'backdrop_path': '/cpTjuXuNTE...          171
# 7      2  {'adult': False, 'backdrop_path': '/uZMZyvarQu...          171
# 8      2  {'adult': False, 'backdrop_path': '/tintsaQ0WL...          171
# 9      2  {'adult': False, 'backdrop_path': '/s3tGKy9ZD6...          171
# 10     2  {'adult': False, 'backdrop_path': '/xcUf6yIheo...          171
# 11     2  {'adult': False, 'backdrop_path': '/8xItDmrhT6...          171
# ...

# %%
# Getting the frame for "results"
pd.DataFrame(data["results"])
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /oj9pEWQq5higRzKWiE8f0d5hBSb.jpg             [53, 27, 18]  617708
# 1   False  /yFRpUmsreYO5Bc0HVBTsJsHIIox.jpg          [18, 12, 10751]  481848
# 2   False  /jZ6NrikuKX1Wby0EeT91BVDv45o.jpg      [16, 12, 28, 10751]  657561
# 3   False  /hqYe7wfxv6HyGBlEh151Z2l9M2S.jpg                 [27, 35]  728144
# 4   False  /p9tdFuUe1Xc9YYMmPcqMczttnvG.jpg  [16, 35, 28, 12, 10751]  550738
# 5   False  /a8ppJJIQmEJcLSFfhxupc4aT4KW.jpg             [18, 28, 53]  571785
# 6   False  /cpTjuXuNTEDJc7qJEiUbUGcn85F.jpg                 [27, 35]  664168
# 7   False  /uZMZyvarQuXLRqf3xdpdMqzdtjb.jpg            [53, 878, 27]  570670
# 8   False  /tintsaQ0WLzZsTMkTiqtMB3rfc8.jpg             [28, 80, 35]  522627
# 9   False  /s3tGKy9ZD6KLTRLBsx9ekpvlYd9.jpg              [16, 10751]  619918
# 10  False  /xcUf6yIheo78btFqihlRLftdR3M.jpg      [35, 14, 12, 10751]  448119
# ...

# %% [markdown]
# #### From the above we can usderstand the data more accurately. We can categorize the movies based on "title", "votes", etc.

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %%
import pandas as pd
import requests
import json
pd.options.display.max_columns = 30

# %%
# I am going to use some movies id for this process. I have got it from the site and its just selected id
movie_id = [0, 299534, 19995, 140607, 299536, 597, 135397,
            420818, 24428, 168259, 99861, 284054, 12445,
            181808, 330457, 351286, 109445, 321612, 260513]

# %%
# Getting the url
basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
# Preparing for DataFrame
json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data) 
df = pd.DataFrame(json_list)

# %%
# Preparing for the request
requests.get(basic_url.format(0, api_key)).status_code
# Out:
# 404

# %%
# Checking out the data
df
# Out:
#     adult                     backdrop_path  \
# 0   False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1   False  /AmHOQ7rpHwiaUMRjKXztnauSJb7.jpg
# 2   False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 3   False  /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg
# 4   False  /yDI6D5ZQh67YU4r2ms8qcSbAviZ.jpg
# 5   False  /yOCRqvrRrxbs5FYq2pX1KtLJwmR.jpg
# 6   False  /nRXO2SnOA75OsWhNhXstHB8ZmI3.jpg
# 7   False  /kwUQFeFXOOpgloMgZaadhzkbTI4.jpg
# 8   False  /vkQvqH8WQkUiNklDcbUtHEUgSNQ.jpg
# 9   False  /8i6ZDk97Vyh0jHohMG4vFeFuKJh.jpg
# 10  False  /6ELJEzQJ3Y45HczvreC3dg0GV5R.jpg
# 11  False  /n5A7brJCjejceZmHyujwUTVgQNC.jpg
# 12  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 13  False  /xJWPZIYOEFIjZpBL7SVBGnzRYXp.jpg
# 14  False  /3s9O5af2xWKWR5JzP2iJZpZeQQg.jpg
# 15  False  /fydUcbkqLyESCFa9U5XKqi8dIVj.jpg
# 16  False  /m3tdSyl11fhgXPDSEt3aBctTqGP.jpg
# 17  False  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection     budget  \
# ...

# %%
# Locating the data by using loc syntax
df = df.loc[:, ["title", "id", "revenue", "genres", "belongs_to_collection", "runtime"]].sort_values(by = "revenue",
                                                                                                ascending = False)

# %%
# Checking data again
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 4                                        Titanic     597  2187463944
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1515047671
# 13                                     Frozen II  330457  1450026933
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# ...

# %% [markdown]
# #### So I have data about revenues of 18 movies

# %%
# Lets gets the json file for the above
df.to_json("movies.json", orient = "records")

# %%
with open("movies.json") as f:
    data = json.load(f)

# %%
# Normalizing it
pd.json_normalize(data)
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                                        Titanic     597  2187463944
# 3                   Star Wars: The Force Awakens  140607  2068223624
# 4                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1515047671
# 9                                      Frozen II  330457  1450026933
# 10                       Avengers: Age of Ultron   99861  1405403694
# 11                                 Black Panther  284054  1346739107
# 12  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# ...

# %%
# Normalizing it in case of genres and title
pd.json_normalize(data, "genres", "title")
# Out:
#        id             name                                         title
# 0      12        Adventure                             Avengers: Endgame
# 1     878  Science Fiction                             Avengers: Endgame
# 2      28           Action                             Avengers: Endgame
# 3      28           Action                                        Avatar
# 4      12        Adventure                                        Avatar
# 5      14          Fantasy                                        Avatar
# 6     878  Science Fiction                                        Avatar
# 7      18            Drama                                       Titanic
# 8   10749          Romance                                       Titanic
# 9      28           Action                  Star Wars: The Force Awakens
# 10     12        Adventure                  Star Wars: The Force Awakens
# 11    878  Science Fiction                  Star Wars: The Force Awakens
# ...

# %% [markdown]
# ### So i have normalize the data and got the output if movies based on "id", "name" & "title". Now lets save the dataset.

# %% [markdown]
# # Importing and Saving the Movies Dataset (Real World Scenario)

# %%
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 4                                        Titanic     597  2187463944
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1515047671
# 13                                     Frozen II  330457  1450026933
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# ...

# %%
df.to_csv("movies_raw.csv", index = False)

# %%
df = pd.read_csv("movies_raw.csv")

# %%
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                                        Titanic     597  2187463944
# 3                   Star Wars: The Force Awakens  140607  2068223624
# 4                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1515047671
# 9                                      Frozen II  330457  1450026933
# 10                       Avengers: Age of Ultron   99861  1405403694
# 11                                 Black Panther  284054  1346739107
# 12  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# ...

# %%
df.genres[0]
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}]"

# %% [markdown]
# ### From this project we can understand that, "Adventure", "Science Fiction" and "Action" are some major genres with respective id's which has highest revenue as well as rating on the TNDB site. I have used json and csv to get final details of the movie dataset.
